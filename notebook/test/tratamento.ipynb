# %% [markdown]
# ### Notebook para tratamento do dataset e recorte e Teste da Segmentação

# %% [markdown]
# ### Geracao dos diretórios necessários

# %%
import os


folders_paths = [
  "../data/base/",
  "../data/base_temporaria",
  "../data/base_recortada",
  "../data/base_mascara"
]


for each in folders_paths:
  if not os.path.exists(each):
    os.mkdir(each)
    print(f'Dirétorio criado: ({each})')

# %% [markdown]
# ### Copiando o base para base_temporaria_teste

# %%
raiz = "../data/base"
destino = "../data/base_temporaria"

import shutil

if ".png" in raiz:
    source_file = raiz  
    
    raiz_split = raiz.split("/") 
    
    destination_file = os.path.join(destino, raiz_split[(len(raiz_split)-1)])
    shutil.copy2(raiz, destination_file)
else:
  for i, each_file in enumerate(os.listdir(raiz)):

    source_file = os.path.join(raiz, each_file)
      
    destination_file = os.path.join(destino, each_file)
    print(i)
    
    if os.path.isfile(source_file):
          shutil.copy2(source_file, destination_file)

# %% [markdown]
# ### Recorte da imagem

# %%
import numpy as np
import os
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
diretorio_dataset = "../data/base_temporaria/"
diretorio_dataset_recortado = "../data/base_recortada/"
df = pd.read_csv("../data/classifications.csv")
value_expand = 90

# %%
# df = pd.read_csv("./data/classifications.csv")
# df = df[df["image_filename"] == "363b6b00d925e5c52694b8f7b678c53b.png"]
df = df[df["bethesda_system"] == "ASC-US"]

for each in df.iterrows():
  
  nome_img = each[1]['image_filename']
  nome_da_doenca = each[1]['bethesda_system']
  posi_x = each[1]['nucleus_x']
  posi_y = each[1]['nucleus_y']
  id_celular = each[1]['cell_id']  
  
  path_imagem_dataset_original = f'{diretorio_dataset}{nome_img}'
  print(path_imagem_dataset_original)
  
  # Onde ele vai ler cada imagem;
  img = cv2.imread(path_imagem_dataset_original)
  
  x1 = max(0, posi_x - value_expand)
  y1 = max(0, posi_y - value_expand)
  x2 = min(img.shape[1], posi_x + value_expand)
  y2 = min(img.shape[0], posi_y + value_expand)
  
  # Recortando a imagem;
  img_recortada = img[y1:y2,x1:x2]
  
  # Verifica se existe um folder no destino com o nome da doenca;
  if not os.path.exists(os.path.join(diretorio_dataset_recortado, nome_da_doenca)):
    os.mkdir(os.path.join(diretorio_dataset_recortado, nome_da_doenca))
    
  # Salva a imagem recortada no novo destino
  
  # print(len(img_recortada))
  
  
  
  if(len(img_recortada)!= 0):    
    try:
      cv2.imwrite(f'{diretorio_dataset_recortado}{nome_da_doenca}/' + f'{id_celular}.png', img_recortada)
    except:
      print(id_celular)
  # Limpar a variavel cv2
  cv2.destroyAllWindows()
# Out:
# ../data/base_temporaria/0cc6e576dac3046d279bba515e10a7a9.png
# ../data/base_temporaria/0cc6e576dac3046d279bba515e10a7a9.png
# ../data/base_temporaria/6a642a0409ea6f1ffd234d666d6c9319.png
# ../data/base_temporaria/b5bc96650b0315465891547e78e4490c.png
# ../data/base_temporaria/b5bc96650b0315465891547e78e4490c.png
# ../data/base_temporaria/b5bc96650b0315465891547e78e4490c.png
# ../data/base_temporaria/b5bc96650b0315465891547e78e4490c.png
# ../data/base_temporaria/5b7cc4b7d0373fab44cc5686ba477e0c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/9d0f43b29d78f673e9caf77928b4af3c.png
# ../data/base_temporaria/be340ee72689dfe3f8dc9c24de6127f4.png

# %%
def listar_imagens(diretorio_raiz, extensoes_imagens=None):
    if extensoes_imagens is None:
        extensoes_imagens = ['.jpg', '.jpeg', '.png']

    arquivos_imagens = []
    for dirpath, _, filenames in os.walk(diretorio_raiz):
        for filename in filenames:
            if any(filename.lower().endswith(extensao) for extensao in extensoes_imagens):
                caminho_completo = os.path.join(dirpath, filename)
                arquivos_imagens.append(caminho_completo)
    return arquivos_imagens
  
def exibir_imagens(lista_de_caminhos, largura=40, altura=25, path=True):
    num_imagens = len(lista_de_caminhos)
    
    if path:
    
      fig, axes = plt.subplots(1, num_imagens, figsize=(largura, altura))
    
      for i, caminho in enumerate(lista_de_caminhos):

          imagem = Image.open(caminho)
            
          axes[i].imshow(imagem)
          axes[i].axis('off')
          img = caminho.split("/")
          img = img[len(img)-1].replace("\\", " ").replace(".png", "")
          if "for" in img:
            img = img.replace("for intraepithelial lesion", "")
          axes[i].set_title(img)
      plt.show()
    else:
      
      # map_celula = {
      #   "title" : None,
      #   "img-inteira-title": None,
      #   "img-inteira-plotada" : None,
      #   "img" : None,
      #   "img-seg" : None,
      #   "img-mask" : None,
      # }
      fig, axes = plt.subplots(nrows=len(lista_de_caminhos), ncols=3, figsize=(largura, altura))
      plt.subplots_adjust(wspace=0.2)
      
      for i, each in enumerate(lista_de_caminhos):

          
          
          # Plotar imagem segmentada
          axes[i, 1].imshow(each["img-seg"])
          axes[i, 1].axis('off')
          if "for" in each["title"]:
            axes[i, 1].set_title(f'Segmentada  - {each["title"].replace("for intraepithelial lesion", "")}')
          else:
            axes[i, 1].set_title(f'Segmentada  - {each["title"]}')
              
          
          # Plotar original
          axes[i, 0].imshow(each["img"])
          axes[i, 0].axis('off')
          
          if "for" in each["title"]:
            
            axes[i, 0].set_title(f'Original - {each["title"].replace("for intraepithelial lesion", "")}')
          else:
            axes[i, 0].set_title(f'Original - {each["title"]}')
          # Plotar mask
          
          axes[i, 2].imshow(each["img-mask"])
          axes[i, 2].axis('off')
          if "for" in each["title"]:
            axes[i, 2].set_title(f'Mask - {each["title"].replace("for intraepithelial lesion", "")}')
          else:
            axes[i, 2].set_title(f'Mask - {each["title"]}')
            
      plt.show()

# %%
directory_path = '../data/base_recortada/'
images = listar_imagens(directory_path)
exibir_imagens(images)

# %% [markdown]
# Bibliotecas de Segmentação

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Inicio do Método de Remover Fundo (INPUT IMG INTEIRA)

# %%
def remover_fundo_com_grabcut(imagem, x_central, y_central, tamanho_retangulo):
    mascara = np.zeros(imagem.shape[:2], np.uint8)
    backgroundModel = np.zeros((1, 65), np.float64)
    foregroundModel = np.zeros((1, 65), np.float64)
    altura, largura = imagem.shape[:2]
    
    x1 = max(0, x_central - tamanho_retangulo // 2)
    y1 = max(0, y_central - tamanho_retangulo // 2)
    x2 = min(largura, x_central + tamanho_retangulo // 2)
    y2 = min(altura, y_central + tamanho_retangulo // 2)
    
    rectangle = (x1, y1, x2 - x1, y2 - y1)
    
    cv2.grabCut(imagem, mascara, rectangle,  
            backgroundModel, foregroundModel,
            3, cv2.GC_INIT_WITH_RECT)
    
    mascara_objeto = np.where((mascara == 2) | (mascara == 0), 0, 1).astype('uint8')
    
    imagem_sem_fundo = imagem * mascara_objeto[:, :, np.newaxis]
    
    img_recortada = imagem_sem_fundo[y1:y2, x1:x2]
    
    imagem_gray = cv2.cvtColor(img_recortada, cv2.COLOR_BGR2GRAY)
    
    _, mascara = cv2.threshold(imagem_gray, 10, 255, cv2.THRESH_BINARY)
    
    img_original_recortada = imagem[y1:y2, x1:x2]
    
    return img_recortada, mascara, img_original_recortada

# %%
def paint_quadrado_imagem_original(imagem, x_central, y_central, value_expand):
  x1 = max(0, x_central - value_expand // 2)
  y1 = max(0, y_central - value_expand // 2)
  x2 = min(imagem.shape[1], x_central + value_expand // 2)
  y2 = min(imagem.shape[0], y_central + value_expand // 2)

  imagem_com_quadrado = imagem.copy()
  cv2.rectangle(imagem_com_quadrado, (x1, y1), (x2, y2), (0, 255, 0), 2)  
  cv2.circle(imagem_com_quadrado, (x_central, y_central), 5, (0, 0, 255), -1) 

  imagem_com_quadrado_rgb = cv2.cvtColor(imagem_com_quadrado, cv2.COLOR_BGR2RGB)
  return imagem_com_quadrado_rgb

# %%
def generateMapSegmentad(lista_map_celula, img_name, value_expand):
  # value_expand = 70
  df = pd.read_csv("../data/classifications.csv")
  df = df[df["image_filename"] == f"{img_name}.png"]
  database = "../data/base_temporaria/"

  map_celula = {
    "title" : None,
    "img-inteira-title": None,
    "img-inteira-plotada" : None,
    "img" : None,
    "img-seg" : None,
    "img-mask" : None,
  }

  

  for i, each in enumerate(df.iterrows()):
    
    
    nome_img = each[1]['image_filename']
    nome_da_doenca = each[1]['bethesda_system']
    posi_x = each[1]['nucleus_x']
    posi_y = each[1]['nucleus_y']
    id_celular = each[1]['cell_id']  
    
    path = "".join([database, nome_img])
    
    imagem = cv2.imread(path)
    imagem_sem_fundo, mask, img_original_recortada = remover_fundo_com_grabcut(imagem, posi_x, posi_y, value_expand)
    
    map_celula["img"] = img_original_recortada
    map_celula["title"] = f"{nome_da_doenca} - {id_celular}"
    map_celula["img-inteira-title"] = nome_img
    map_celula["img-seg"] = imagem_sem_fundo
    map_celula["img-mask"] = mask
    
    if i == 0:
      imagem_original_plotada = paint_quadrado_imagem_original(imagem, posi_x, posi_y, value_expand)
    else:
      imagem_original_plotada = paint_quadrado_imagem_original(imagem_original_plotada, posi_x, posi_y, value_expand)
    
    map_celula["img-inteira-plotada"] = imagem_original_plotada
    lista_map_celula.append(map_celula.copy())
    # print(i)
    print(nome_da_doenca +  " " + str(id_celular))
  return lista_map_celula

# %% [markdown]
# ### Inicio do Método de Remover Fundo (INPUT IMG RECORTADA)

# %%
def remover_fundo_com_grabcut_recortado(imagem):
    mascara = np.zeros(imagem.shape[:2], np.uint8)
    backgroundModel = np.zeros((1, 65), np.float64)
    foregroundModel = np.zeros((1, 65), np.float64)
    altura, largura = imagem.shape[:2]
    
    # Calcular os limites do retângulo
    x1 = 0
    y1 = 0
    x2 = largura - 1
    y2 = altura - 1
        
    rectangle = (x1, y1, x2 - x1, y2 - y1)
    
    print(f"Valor do ratangulo: {rectangle}")
    
    cv2.grabCut(imagem, mascara, rectangle,  
            backgroundModel, foregroundModel,
            3, cv2.GC_INIT_WITH_RECT)
    
    mascara_objeto = np.where((mascara == 2) | (mascara == 0), 0, 1).astype('uint8')
    
    imagem_sem_fundo = imagem * mascara_objeto[:, :, np.newaxis]
    
    img_recortada = imagem_sem_fundo[y1:y2, x1:x2]
    
    imagem_gray = cv2.cvtColor(img_recortada, cv2.COLOR_BGR2GRAY)
    
    _, mascara = cv2.threshold(imagem_gray, 10, 255, cv2.THRESH_BINARY)
    
    img_original_recortada = imagem[y1:y2, x1:x2]
    
    return img_recortada, mascara, img_original_recortada

# %%
def paint_quadrado_imagem_recortado(imagem, x_central, y_central):
  altura, largura = imagem.shape[:2]
    
  # Calcular os limites do retângulo
  x1 = 0
  y1 = 0
  x2 = largura - 1
  y2 = altura - 1

  imagem_com_quadrado = imagem.copy()
  cv2.rectangle(imagem_com_quadrado, (x1, y1), (x2, y2), (0, 255, 0), 2)  
  cv2.circle(imagem_com_quadrado, (x_central, y_central), 5, (0, 0, 255), -1) 

  imagem_com_quadrado_rgb = cv2.cvtColor(imagem_com_quadrado, cv2.COLOR_BGR2RGB)
  return imagem_com_quadrado_rgb

# %%
def generateMapSegmentad_Recortada(lista_map_celula, info_img):
  # value_expand = 70
  df = pd.read_csv("../data/classifications.csv")
  # df = df[df["image_filename"] == f"{info_img}.png"]
  df = df[df["cell_id"] == int(info_img) ]

  print(df)
  print("AAAAAAAAAAAAAAAAAAAAA")
  print(int(info_img))
  print("--------------\n\n\n")
  map_celula = {
    "title" : None,
    "img-inteira-title": None,
    "img-inteira-plotada" : None,
    "img" : None,
    "img-seg" : None,
    "img-mask" : None,
  }

  

  for i, each in enumerate(df.iterrows()):
    
    print("BBBBBBBBBBBBBBBBBBBBBBBBB")    
    
    nome_img = each[1]['image_filename']
    nome_da_doenca = each[1]['bethesda_system']
    id_celular = each[1]['cell_id']  
    
    database = f"../data/base_recortada/{nome_da_doenca}/"
    
    try:
      
    
      path = "".join([database, str(id_celular)]) + ".png"
      print(path)
      imagem = cv2.imread(path)
      altura, largura = imagem.shape[:2]
      posi_x = largura // 2
      posi_y =  altura // 2
      imagem_sem_fundo, mask, img_original_recortada = remover_fundo_com_grabcut_recortado(imagem)
      
      map_celula["img"] = img_original_recortada
      map_celula["title"] = f"{nome_da_doenca} - {id_celular}"
      map_celula["img-inteira-title"] = nome_img
      map_celula["img-seg"] = imagem_sem_fundo
      map_celula["img-mask"] = mask
      
      if i == 0:
        imagem_original_plotada = paint_quadrado_imagem_recortado(imagem, posi_x, posi_y)
      else:
        imagem_original_plotada = paint_quadrado_imagem_recortado(imagem_original_plotada, posi_x, posi_y)
      
      map_celula["img-inteira-plotada"] = imagem_original_plotada
      lista_map_celula.append(map_celula.copy())
      # print(i)
      print(nome_da_doenca +  " " + str(id_celular))
    except:
      print(f"Deu erro: {database}")
  return lista_map_celula

# %%
lista_map_celula = []
lista_map_celula_recortada = []

generateMapSegmentad_Recortada(lista_map_celula, "363b6b00d925e5c52694b8f7b678c53b")
generateMapSegmentad(lista_map_celula_recortada, "363b6b00d925e5c52694b8f7b678c53b", 70)

# %%
exibir_imagens(lista_de_caminhos=lista_map_celula, largura=40, altura=25, path=False)

# %%
exibir_imagens(lista_de_caminhos=lista_map_celula_recortada, largura=40, altura=25, path=False)

# %%
plt.imshow(lista_map_celula[len(lista_map_celula)-1].get("img-inteira-plotada"))
plt.axis('off')
plt.show()

# %%
lista_map_celula = []

lista_map_celula = generateMapSegmentad(lista_map_celula, "0a2a5a681410054941cc56f51eb8fbda", 100)

# %%
exibir_imagens(lista_de_caminhos=lista_map_celula, largura=40, altura=25, path=False)

# %%
plt.imshow(lista_map_celula[len(lista_map_celula)-1].get("img-inteira-plotada"))
plt.axis('off')
plt.show()

# %%
lista_map_celula = []

lista_map_celula = generateMapSegmentad(lista_map_celula, "1c900ddde4d55e63c0d06c4854b29f89", 90)

# %%
exibir_imagens(lista_de_caminhos=lista_map_celula, largura=40, altura=25, path=False)

# %%
plt.imshow(lista_map_celula[len(lista_map_celula)-1].get("img-inteira-plotada"))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Gerando Dataset de Mascaras

# %%
# map_celula = {
#   "title" : None,
#   "img-inteira-title": None,
#   "img-inteira-plotada" : None,
#   "img" : None,
#   "img-seg" : None,
#   "img-mask" : None,
# }

# %%
diretorio_dataset_recortado_mask = "../data/base_mascara/"

# %%
def listar_imagens(diretorio_raiz, extensoes_imagens=None):
    if extensoes_imagens is None:
        extensoes_imagens = ['.jpg', '.jpeg', '.png']

    arquivos_imagens = []
    for dirpath, _, filenames in os.walk(diretorio_raiz):
        for filename in filenames:
            if any(filename.lower().endswith(extensao) for extensao in extensoes_imagens):
                caminho_completo = os.path.join(dirpath, filename)
                arquivos_imagens.append(caminho_completo)
    return arquivos_imagens

# %%
path = '../data/base_recortada/'
img_path_list = []
img_path_list = listar_imagens(path)


for each_img in img_path_list:
  lista_map_celula = []
  
  # img_name = each_img.split("/")
  # img_name = img_name[len(img_name)-1].replace(".png", "")
  img_name = each_img.split('\\')
  img_name = img_name[len(img_name)-1].replace(".png", "")

  lista_map_celula = generateMapSegmentad_Recortada(lista_map_celula, img_name)
  
  for each_map in lista_map_celula:
    
    title = each_map["title"].split("-")
    id_celular = title[len(title)-1].strip()
    nome_da_doenca = title[0].strip()
    
    if(len(each_map["img-mask"])!= 0):    

      if not os.path.exists(os.path.join(diretorio_dataset_recortado_mask, nome_da_doenca)):
        os.mkdir(os.path.join(diretorio_dataset_recortado_mask, nome_da_doenca))
    
      try:
        cv2.imwrite(f'{diretorio_dataset_recortado_mask}{nome_da_doenca}/' + f'{id_celular}.png', each_map["img-mask"])
      except:
        print("Erro")
        print(each_map["title"])
# Out:
#     image_id                        image_filename  \
# 99       398  0cc6e576dac3046d279bba515e10a7a9.png
#
#                        image_doi  cell_id bethesda_system  nucleus_x  \
# 99  10.6084/m9.figshare.12230900      100          ASC-US       1118
#
#     nucleus_y
# 99         31
# AAAAAAAAAAAAAAAAAAAAA
# 100
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/100.png
# Valor do ratangulo: (0, 0, 179, 120)
# ASC-US 100
#       image_id                        image_filename  \
# 1003       378  b7c9bdb02733f1e3d77ac191115c15f7.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1003  10.6084/m9.figshare.12230816     1004          ASC-US        583
#
#       nucleus_y
# 1003        567
# AAAAAAAAAAAAAAAAAAAAA
# 1004
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1004.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1004
#        image_id                        image_filename  \
# 10140        42  45c237e071148a104c2770fbca5e67a8.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10140  10.6084/m9.figshare.12229652    10141          ASC-US        583
#
#        nucleus_y
# 10140        792
# AAAAAAAAAAAAAAAAAAAAA
# 10141
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10141.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10141
#        image_id                        image_filename  \
# 10168        41  33708abb81e40ff45d1510c44546e82f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10168  10.6084/m9.figshare.12229649    10169          ASC-US        592
#
#        nucleus_y
# 10168        822
# AAAAAAAAAAAAAAAAAAAAA
# 10169
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10169.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10169
#        image_id                        image_filename  \
# 10169        41  33708abb81e40ff45d1510c44546e82f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10169  10.6084/m9.figshare.12229649    10170          ASC-US        584
#
#        nucleus_y
# 10169        848
# AAAAAAAAAAAAAAAAAAAAA
# 10170
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10170.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10170
#        image_id                        image_filename  \
# 10170        41  33708abb81e40ff45d1510c44546e82f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10170  10.6084/m9.figshare.12229649    10171          ASC-US       1225
#
#        nucleus_y
# 10170         40
# AAAAAAAAAAAAAAAAAAAAA
# 10171
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10171.png
# Valor do ratangulo: (0, 0, 179, 129)
# ASC-US 10171
#        image_id                        image_filename  \
# 10171        41  33708abb81e40ff45d1510c44546e82f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10171  10.6084/m9.figshare.12229649    10172          ASC-US       1209
#
#        nucleus_y
# 10171        223
# AAAAAAAAAAAAAAAAAAAAA
# 10172
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10172.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10172
#        image_id                        image_filename  \
# 10187        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10187  10.6084/m9.figshare.12229643    10188          ASC-US        252
#
#        nucleus_y
# 10187        750
# AAAAAAAAAAAAAAAAAAAAA
# 10188
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10188.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10188
#        image_id                        image_filename  \
# 10188        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10188  10.6084/m9.figshare.12229643    10189          ASC-US        832
#
#        nucleus_y
# 10188        424
# AAAAAAAAAAAAAAAAAAAAA
# 10189
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10189.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10189
#        image_id                        image_filename  \
# 10189        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10189  10.6084/m9.figshare.12229643    10190          ASC-US        993
#
#        nucleus_y
# 10189         34
# AAAAAAAAAAAAAAAAAAAAA
# 10190
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10190.png
# Valor do ratangulo: (0, 0, 179, 123)
# ASC-US 10190
#        image_id                        image_filename  \
# 10190        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10190  10.6084/m9.figshare.12229643    10191          ASC-US        959
#
#        nucleus_y
# 10190         33
# AAAAAAAAAAAAAAAAAAAAA
# 10191
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10191.png
# Valor do ratangulo: (0, 0, 179, 122)
# ASC-US 10191
#        image_id                        image_filename  \
# 10205        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10205  10.6084/m9.figshare.12229643    10206          ASC-US       1013
#
#        nucleus_y
# 10205        261
# AAAAAAAAAAAAAAAAAAAAA
# 10206
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10206.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10206
#        image_id                        image_filename  \
# 10206        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10206  10.6084/m9.figshare.12229643    10207          ASC-US        885
#
#        nucleus_y
# 10206        279
# AAAAAAAAAAAAAAAAAAAAA
# 10207
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10207.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10207
#        image_id                        image_filename  \
# 10207        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10207  10.6084/m9.figshare.12229643    10208          ASC-US        948
#
#        nucleus_y
# 10207        983
# AAAAAAAAAAAAAAAAAAAAA
# 10208
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10208.png
# Valor do ratangulo: (0, 0, 179, 126)
# ASC-US 10208
#        image_id                        image_filename  \
# 10210        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10210  10.6084/m9.figshare.12229643    10211          ASC-US        375
#
#        nucleus_y
# 10210        537
# AAAAAAAAAAAAAAAAAAAAA
# 10211
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10211.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10211
#        image_id                        image_filename  \
# 10211        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10211  10.6084/m9.figshare.12229643    10212          ASC-US        379
#
#        nucleus_y
# 10211        558
# AAAAAAAAAAAAAAAAAAAAA
# 10212
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10212.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10212
#        image_id                        image_filename  \
# 10212        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10212  10.6084/m9.figshare.12229643    10213          ASC-US        680
#
#        nucleus_y
# 10212        960
# AAAAAAAAAAAAAAAAAAAAA
# 10213
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10213.png
# Valor do ratangulo: (0, 0, 179, 149)
# ASC-US 10213
#        image_id                        image_filename  \
# 10213        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10213  10.6084/m9.figshare.12229643    10214          ASC-US        525
#
#        nucleus_y
# 10213        884
# AAAAAAAAAAAAAAAAAAAAA
# 10214
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10214.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10214
#        image_id                        image_filename  \
# 10214        39  dd569f426f91cc5d6a20804c800d6eb3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10214  10.6084/m9.figshare.12229643    10215          ASC-US        493
#
#        nucleus_y
# 10214        894
# AAAAAAAAAAAAAAAAAAAAA
# 10215
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10215.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10215
#        image_id                        image_filename  \
# 10349        36  7f725f332e420bc3c96533e342802d4c.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10349  10.6084/m9.figshare.12229631    10350          ASC-US        848
#
#        nucleus_y
# 10349        136
# AAAAAAAAAAAAAAAAAAAAA
# 10350
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10350.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10350
#        image_id                        image_filename  \
# 10363        36  7f725f332e420bc3c96533e342802d4c.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10363  10.6084/m9.figshare.12229631    10364          ASC-US        898
#
#        nucleus_y
# 10363        132
# AAAAAAAAAAAAAAAAAAAAA
# 10364
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10364.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10364
#        image_id                        image_filename  \
# 10365        34  b6bf215df9cc83413a7c5a61c64361da.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10365  10.6084/m9.figshare.12229625    10366          ASC-US        766
#
#        nucleus_y
# 10365        671
# AAAAAAAAAAAAAAAAAAAAA
# 10366
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10366.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10366
#        image_id                        image_filename  \
# 10366        34  b6bf215df9cc83413a7c5a61c64361da.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10366  10.6084/m9.figshare.12229625    10367          ASC-US        689
#
#        nucleus_y
# 10366        481
# AAAAAAAAAAAAAAAAAAAAA
# 10367
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10367.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10367
#        image_id                        image_filename  \
# 10369        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10369  10.6084/m9.figshare.12229619    10370          ASC-US        638
#
#        nucleus_y
# 10369        107
# AAAAAAAAAAAAAAAAAAAAA
# 10370
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10370.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10370
#        image_id                        image_filename  \
# 10370        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10370  10.6084/m9.figshare.12229619    10371          ASC-US        931
#
#        nucleus_y
# 10370        325
# AAAAAAAAAAAAAAAAAAAAA
# 10371
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10371.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10371
#        image_id                        image_filename  \
# 10371        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10371  10.6084/m9.figshare.12229619    10372          ASC-US        818
#
#        nucleus_y
# 10371        438
# AAAAAAAAAAAAAAAAAAAAA
# 10372
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10372.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10372
#        image_id                        image_filename  \
# 10372        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10372  10.6084/m9.figshare.12229619    10373          ASC-US        755
#
#        nucleus_y
# 10372        534
# AAAAAAAAAAAAAAAAAAAAA
# 10373
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10373.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10373
#        image_id                        image_filename  \
# 10373        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10373  10.6084/m9.figshare.12229619    10374          ASC-US        617
#
#        nucleus_y
# 10373        583
# AAAAAAAAAAAAAAAAAAAAA
# 10374
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10374.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10374
#        image_id                        image_filename  \
# 10387        32  ee78da0c06d978fec8d86a8d97182445.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10387  10.6084/m9.figshare.12229619    10388          ASC-US       1012
#
#        nucleus_y
# 10387         22
# AAAAAAAAAAAAAAAAAAAAA
# 10388
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10388.png
# Valor do ratangulo: (0, 0, 179, 111)
# ASC-US 10388
#        image_id                        image_filename  \
# 10390        33  07872ee58dea1007dd5d4afa5fb2556d.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10390  10.6084/m9.figshare.12229622    10391          ASC-US        475
#
#        nucleus_y
# 10390        733
# AAAAAAAAAAAAAAAAAAAAA
# 10391
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10391.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10391
#       image_id                        image_filename  \
# 1039       377  b849f2f30721992da28419731f8c4d21.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1039  10.6084/m9.figshare.12230813     1040          ASC-US       1020
#
#       nucleus_y
# 1039        800
# AAAAAAAAAAAAAAAAAAAAA
# 1040
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1040.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1040
#        image_id                        image_filename  \
# 10436        31  88e5e1814b1a2c4d30e28f8b98ba157c.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10436  10.6084/m9.figshare.12229616    10437          ASC-US        820
#
#        nucleus_y
# 10436        607
# AAAAAAAAAAAAAAAAAAAAA
# 10437
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10437.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10437
#       image_id                        image_filename  \
# 1045       376  da21a895881b3ba7d6108dba4a4ce17a.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1045  10.6084/m9.figshare.12230810     1046          ASC-US        680
#
#       nucleus_y
# 1045        501
# AAAAAAAAAAAAAAAAAAAAA
# 1046
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1046.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1046
#       image_id                        image_filename  \
# 1050       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1050  10.6084/m9.figshare.12230807     1051          ASC-US       1113
#
#       nucleus_y
# 1050        542
# AAAAAAAAAAAAAAAAAAAAA
# 1051
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1051.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1051
#       image_id                        image_filename  \
# 1051       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1051  10.6084/m9.figshare.12230807     1052          ASC-US        969
#
#       nucleus_y
# 1051        450
# AAAAAAAAAAAAAAAAAAAAA
# 1052
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1052.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1052
#       image_id                        image_filename  \
# 1052       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1052  10.6084/m9.figshare.12230807     1053          ASC-US       1069
#
#       nucleus_y
# 1052        419
# AAAAAAAAAAAAAAAAAAAAA
# 1053
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1053.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1053
#       image_id                        image_filename  \
# 1053       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1053  10.6084/m9.figshare.12230807     1054          ASC-US       1059
#
#       nucleus_y
# 1053        391
# AAAAAAAAAAAAAAAAAAAAA
# 1054
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1054.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1054
#       image_id                        image_filename  \
# 1054       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1054  10.6084/m9.figshare.12230807     1055          ASC-US       1127
#
#       nucleus_y
# 1054        295
# AAAAAAAAAAAAAAAAAAAAA
# 1055
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1055.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1055
#       image_id                        image_filename  \
# 1055       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1055  10.6084/m9.figshare.12230807     1056          ASC-US       1245
#
#       nucleus_y
# 1055        422
# AAAAAAAAAAAAAAAAAAAAA
# 1056
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1056.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1056
#        image_id                        image_filename  \
# 10560        29  92f442dda43d7250c63ba2823c96be42.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10560  10.6084/m9.figshare.12229610    10561          ASC-US        357
#
#        nucleus_y
# 10560        120
# AAAAAAAAAAAAAAAAAAAAA
# 10561
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10561.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10561
#       image_id                        image_filename  \
# 1056       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1056  10.6084/m9.figshare.12230807     1057          ASC-US       1239
#
#       nucleus_y
# 1056        544
# AAAAAAAAAAAAAAAAAAAAA
# 1057
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1057.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1057
#       image_id                        image_filename  \
# 1057       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1057  10.6084/m9.figshare.12230807     1058          ASC-US         57
#
#       nucleus_y
# 1057        555
# AAAAAAAAAAAAAAAAAAAAA
# 1058
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1058.png
# Valor do ratangulo: (0, 0, 146, 179)
# ASC-US 1058
#       image_id                        image_filename  \
# 1058       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1058  10.6084/m9.figshare.12230807     1059          ASC-US        155
#
#       nucleus_y
# 1058        590
# AAAAAAAAAAAAAAAAAAAAA
# 1059
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1059.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1059
#       image_id                        image_filename  \
# 1059       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1059  10.6084/m9.figshare.12230807     1060          ASC-US        175
#
#       nucleus_y
# 1059        555
# AAAAAAAAAAAAAAAAAAAAA
# 1060
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1060.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1060
#       image_id                        image_filename  \
# 1060       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1060  10.6084/m9.figshare.12230807     1061          ASC-US        292
#
#       nucleus_y
# 1060        572
# AAAAAAAAAAAAAAAAAAAAA
# 1061
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1061.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1061
#       image_id                        image_filename  \
# 1061       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1061  10.6084/m9.figshare.12230807     1062          ASC-US        290
#
#       nucleus_y
# 1061        714
# AAAAAAAAAAAAAAAAAAAAA
# 1062
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1062.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1062
#       image_id                        image_filename  \
# 1062       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1062  10.6084/m9.figshare.12230807     1063          ASC-US        193
#
#       nucleus_y
# 1062        742
# AAAAAAAAAAAAAAAAAAAAA
# 1063
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1063.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1063
#       image_id                        image_filename  \
# 1063       375  78d680144e599148615a263fb6048f66.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1063  10.6084/m9.figshare.12230807     1064          ASC-US        132
#
#       nucleus_y
# 1063        674
# AAAAAAAAAAAAAAAAAAAAA
# 1064
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1064.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1064
#        image_id                        image_filename  \
# 10651        26  584d79af21c45131e9af9d54d2c2b8e4.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10651  10.6084/m9.figshare.12229601    10652          ASC-US        241
#
#        nucleus_y
# 10651        795
# AAAAAAAAAAAAAAAAAAAAA
# 10652
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10652.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10652
#        image_id                        image_filename  \
# 10717        26  584d79af21c45131e9af9d54d2c2b8e4.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10717  10.6084/m9.figshare.12229601    10718          ASC-US        201
#
#        nucleus_y
# 10717        485
# AAAAAAAAAAAAAAAAAAAAA
# 10718
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10718.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10718
#        image_id                        image_filename  \
# 10718        26  584d79af21c45131e9af9d54d2c2b8e4.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10718  10.6084/m9.figshare.12229601    10719          ASC-US        333
#
#        nucleus_y
# 10718        477
# AAAAAAAAAAAAAAAAAAAAA
# 10719
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10719.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10719
#       image_id                        image_filename  \
# 1071       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1071  10.6084/m9.figshare.12230804     1072          ASC-US       1055
#
#       nucleus_y
# 1071        314
# AAAAAAAAAAAAAAAAAAAAA
# 1072
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1072.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1072
#        image_id                        image_filename  \
# 10719        26  584d79af21c45131e9af9d54d2c2b8e4.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10719  10.6084/m9.figshare.12229601    10720          ASC-US        447
#
#        nucleus_y
# 10719        447
# AAAAAAAAAAAAAAAAAAAAA
# 10720
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10720.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10720
#       image_id                        image_filename  \
# 1072       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1072  10.6084/m9.figshare.12230804     1073          ASC-US       1165
#
#       nucleus_y
# 1072        284
# AAAAAAAAAAAAAAAAAAAAA
# 1073
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1073.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1073
#       image_id                        image_filename  \
# 1073       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1073  10.6084/m9.figshare.12230804     1074          ASC-US       1214
#
#       nucleus_y
# 1073        414
# AAAAAAAAAAAAAAAAAAAAA
# 1074
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1074.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1074
#       image_id                        image_filename  \
# 1074       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1074  10.6084/m9.figshare.12230804     1075          ASC-US       1145
#
#       nucleus_y
# 1074        491
# AAAAAAAAAAAAAAAAAAAAA
# 1075
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1075.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1075
#        image_id                        image_filename  \
# 10757        24  e49e5d68eaf20468db941ac76632674f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10757  10.6084/m9.figshare.12229595    10758          ASC-US        650
#
#        nucleus_y
# 10757        548
# AAAAAAAAAAAAAAAAAAAAA
# 10758
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10758.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10758
#        image_id                        image_filename  \
# 10758        24  e49e5d68eaf20468db941ac76632674f.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10758  10.6084/m9.figshare.12229595    10759          ASC-US        622
#
#        nucleus_y
# 10758        548
# AAAAAAAAAAAAAAAAAAAAA
# 10759
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10759.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10759
#       image_id                        image_filename  \
# 1075       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1075  10.6084/m9.figshare.12230804     1076          ASC-US       1009
#
#       nucleus_y
# 1075        579
# AAAAAAAAAAAAAAAAAAAAA
# 1076
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1076.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1076
#       image_id                        image_filename  \
# 1076       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1076  10.6084/m9.figshare.12230804     1077          ASC-US       1189
#
#       nucleus_y
# 1076        640
# AAAAAAAAAAAAAAAAAAAAA
# 1077
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1077.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1077
#        image_id                        image_filename  \
# 10771        25  f981c4aac622d7cce71a81305dd38ade.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10771  10.6084/m9.figshare.12229598    10772          ASC-US        604
#
#        nucleus_y
# 10771        498
# AAAAAAAAAAAAAAAAAAAAA
# 10772
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10772.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10772
#        image_id                        image_filename  \
# 10772        25  f981c4aac622d7cce71a81305dd38ade.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10772  10.6084/m9.figshare.12229598    10773          ASC-US        593
#
#        nucleus_y
# 10772        534
# AAAAAAAAAAAAAAAAAAAAA
# 10773
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10773.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10773
#       image_id                        image_filename  \
# 1077       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1077  10.6084/m9.figshare.12230804     1078          ASC-US        999
#
#       nucleus_y
# 1077        426
# AAAAAAAAAAAAAAAAAAAAA
# 1078
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1078.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1078
#       image_id                        image_filename  \
# 1078       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1078  10.6084/m9.figshare.12230804     1079          ASC-US        968
#
#       nucleus_y
# 1078        425
# AAAAAAAAAAAAAAAAAAAAA
# 1079
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1079.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1079
#       image_id                        image_filename  \
# 1079       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1079  10.6084/m9.figshare.12230804     1080          ASC-US        937
#
#       nucleus_y
# 1079        360
# AAAAAAAAAAAAAAAAAAAAA
# 1080
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1080.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1080
#       image_id                        image_filename  \
# 1080       374  39f65c61194a94113080add1c7d5a198.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1080  10.6084/m9.figshare.12230804     1081          ASC-US        927
#
#       nucleus_y
# 1080        582
# AAAAAAAAAAAAAAAAAAAAA
# 1081
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1081.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1081
#        image_id                        image_filename  \
# 10880        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10880  10.6084/m9.figshare.12229592    10881          ASC-US        413
#
#        nucleus_y
# 10880        780
# AAAAAAAAAAAAAAAAAAAAA
# 10881
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10881.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10881
#        image_id                        image_filename  \
# 10881        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10881  10.6084/m9.figshare.12229592    10882          ASC-US        410
#
#        nucleus_y
# 10881        764
# AAAAAAAAAAAAAAAAAAAAA
# 10882
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10882.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10882
#        image_id                        image_filename  \
# 10882        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10882  10.6084/m9.figshare.12229592    10883          ASC-US        396
#
#        nucleus_y
# 10882        716
# AAAAAAAAAAAAAAAAAAAAA
# 10883
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10883.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10883
#        image_id                        image_filename  \
# 10883        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10883  10.6084/m9.figshare.12229592    10884          ASC-US        364
#
#        nucleus_y
# 10883        743
# AAAAAAAAAAAAAAAAAAAAA
# 10884
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10884.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10884
#        image_id                        image_filename  \
# 10884        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10884  10.6084/m9.figshare.12229592    10885          ASC-US        505
#
#        nucleus_y
# 10884        447
# AAAAAAAAAAAAAAAAAAAAA
# 10885
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10885.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10885
#        image_id                        image_filename  \
# 10885        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10885  10.6084/m9.figshare.12229592    10886          ASC-US        476
#
#        nucleus_y
# 10885        468
# AAAAAAAAAAAAAAAAAAAAA
# 10886
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10886.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10886
#        image_id                        image_filename  \
# 10886        23  77acea6065f24cef2351ef3bc2af43a1.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10886  10.6084/m9.figshare.12229592    10887          ASC-US        417
#
#        nucleus_y
# 10886        236
# AAAAAAAAAAAAAAAAAAAAA
# 10887
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10887.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10887
#       image_id                        image_filename  \
# 1088       373  19b7ae0c1983488b205056be14cb8d3f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1088  10.6084/m9.figshare.12230801     1089          ASC-US        782
#
#       nucleus_y
# 1088        459
# AAAAAAAAAAAAAAAAAAAAA
# 1089
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1089.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1089
#       image_id                        image_filename  \
# 1089       373  19b7ae0c1983488b205056be14cb8d3f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1089  10.6084/m9.figshare.12230801     1090          ASC-US        645
#
#       nucleus_y
# 1089        535
# AAAAAAAAAAAAAAAAAAAAA
# 1090
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1090.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1090
#       image_id                        image_filename  \
# 1090       373  19b7ae0c1983488b205056be14cb8d3f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1090  10.6084/m9.figshare.12230801     1091          ASC-US        545
#
#       nucleus_y
# 1090        599
# AAAAAAAAAAAAAAAAAAAAA
# 1091
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1091.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1091
#        image_id                        image_filename  \
# 10924        21  faf0a263bf469832c7569a5ccbaa48c3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10924  10.6084/m9.figshare.12229586    10925          ASC-US        840
#
#        nucleus_y
# 10924        657
# AAAAAAAAAAAAAAAAAAAAA
# 10925
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10925.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10925
#        image_id                        image_filename  \
# 10925        21  faf0a263bf469832c7569a5ccbaa48c3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10925  10.6084/m9.figshare.12229586    10926          ASC-US        825
#
#        nucleus_y
# 10925        629
# AAAAAAAAAAAAAAAAAAAAA
# 10926
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10926.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10926
#        image_id                        image_filename  \
# 10926        21  faf0a263bf469832c7569a5ccbaa48c3.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10926  10.6084/m9.figshare.12229586    10927          ASC-US        742
#
#        nucleus_y
# 10926        530
# AAAAAAAAAAAAAAAAAAAAA
# 10927
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10927.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10927
#        image_id                        image_filename  \
# 10945        19  8457af003b1ad48e907156b5e6e53bea.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10945  10.6084/m9.figshare.12229580    10946          ASC-US        848
#
#        nucleus_y
# 10945        690
# AAAAAAAAAAAAAAAAAAAAA
# 10946
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10946.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10946
#        image_id                        image_filename  \
# 10946        19  8457af003b1ad48e907156b5e6e53bea.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10946  10.6084/m9.figshare.12229580    10947          ASC-US       1007
#
#        nucleus_y
# 10946        941
# AAAAAAAAAAAAAAAAAAAAA
# 10947
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10947.png
# Valor do ratangulo: (0, 0, 179, 168)
# ASC-US 10947
#        image_id                        image_filename  \
# 10947        19  8457af003b1ad48e907156b5e6e53bea.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10947  10.6084/m9.figshare.12229580    10948          ASC-US        990
#
#        nucleus_y
# 10947        904
# AAAAAAAAAAAAAAAAAAAAA
# 10948
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10948.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10948
#        image_id                        image_filename  \
# 10948        19  8457af003b1ad48e907156b5e6e53bea.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10948  10.6084/m9.figshare.12229580    10949          ASC-US        849
#
#        nucleus_y
# 10948        580
# AAAAAAAAAAAAAAAAAAAAA
# 10949
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10949.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10949
#        image_id                        image_filename  \
# 10949        19  8457af003b1ad48e907156b5e6e53bea.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10949  10.6084/m9.figshare.12229580    10950          ASC-US        624
#
#        nucleus_y
# 10949        541
# AAAAAAAAAAAAAAAAAAAAA
# 10950
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10950.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10950
#        image_id                        image_filename  \
# 10983        20  edc748c10f4cd73535452d54b0d7a1a6.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10983  10.6084/m9.figshare.12229583    10984          ASC-US        570
#
#        nucleus_y
# 10983        690
# AAAAAAAAAAAAAAAAAAAAA
# 10984
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10984.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10984
#        image_id                        image_filename  \
# 10990        18  3659bf68aeea760b319cd0710e3651fb.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 10990  10.6084/m9.figshare.12229577    10991          ASC-US        585
#
#        nucleus_y
# 10990        745
# AAAAAAAAAAAAAAAAAAAAA
# 10991
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/10991.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 10991
#        image_id                        image_filename  \
# 11042        16  42e7a4f3bd69279d8b1bc4ea8e248f08.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11042  10.6084/m9.figshare.12229568    11043          ASC-US        425
#
#        nucleus_y
# 11042        441
# AAAAAAAAAAAAAAAAAAAAA
# 11043
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11043.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11043
#        image_id                        image_filename  \
# 11043        16  42e7a4f3bd69279d8b1bc4ea8e248f08.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11043  10.6084/m9.figshare.12229568    11044          ASC-US        374
#
#        nucleus_y
# 11043        321
# AAAAAAAAAAAAAAAAAAAAA
# 11044
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11044.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11044
#       image_id                        image_filename  \
# 1108       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1108  10.6084/m9.figshare.12230795     1109          ASC-US        577
#
#       nucleus_y
# 1108         93
# AAAAAAAAAAAAAAAAAAAAA
# 1109
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1109.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1109
#       image_id                        image_filename  \
# 1109       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1109  10.6084/m9.figshare.12230795     1110          ASC-US        882
#
#       nucleus_y
# 1109        237
# AAAAAAAAAAAAAAAAAAAAA
# 1110
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1110.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1110
#       image_id                        image_filename  \
# 1110       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1110  10.6084/m9.figshare.12230795     1111          ASC-US        782
#
#       nucleus_y
# 1110        476
# AAAAAAAAAAAAAAAAAAAAA
# 1111
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1111.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1111
#        image_id                        image_filename  \
# 11112        14  746c084dbe0b987385df13ddbf4dd635.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11112  10.6084/m9.figshare.12229562    11113          ASC-US        887
#
#        nucleus_y
# 11112        473
# AAAAAAAAAAAAAAAAAAAAA
# 11113
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11113.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11113
#        image_id                        image_filename  \
# 11113        14  746c084dbe0b987385df13ddbf4dd635.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11113  10.6084/m9.figshare.12229562    11114          ASC-US        791
#
#        nucleus_y
# 11113        505
# AAAAAAAAAAAAAAAAAAAAA
# 11114
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11114.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11114
#       image_id                        image_filename  \
# 1111       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1111  10.6084/m9.figshare.12230795     1112          ASC-US        587
#
#       nucleus_y
# 1111        504
# AAAAAAAAAAAAAAAAAAAAA
# 1112
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1112.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1112
#       image_id                        image_filename  \
# 1112       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1112  10.6084/m9.figshare.12230795     1113          ASC-US        482
#
#       nucleus_y
# 1112        722
# AAAAAAAAAAAAAAAAAAAAA
# 1113
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1113.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1113
#       image_id                        image_filename  \
# 1113       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1113  10.6084/m9.figshare.12230795     1114          ASC-US        550
#
#       nucleus_y
# 1113        202
# AAAAAAAAAAAAAAAAAAAAA
# 1114
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1114.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1114
#        image_id                        image_filename  \
# 11140        15  fe7dccb72ee17d6776970bdb5e5ba3ba.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11140  10.6084/m9.figshare.12229565    11141          ASC-US        641
#
#        nucleus_y
# 11140        562
# AAAAAAAAAAAAAAAAAAAAA
# 11141
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11141.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11141
#       image_id                        image_filename  \
# 1114       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1114  10.6084/m9.figshare.12230795     1115          ASC-US        559
#
#       nucleus_y
# 1114        150
# AAAAAAAAAAAAAAAAAAAAA
# 1115
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1115.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1115
#        image_id                        image_filename  \
# 11174        15  fe7dccb72ee17d6776970bdb5e5ba3ba.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11174  10.6084/m9.figshare.12229565    11175          ASC-US        741
#
#        nucleus_y
# 11174        494
# AAAAAAAAAAAAAAAAAAAAA
# 11175
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11175.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11175
#        image_id                        image_filename  \
# 11175        15  fe7dccb72ee17d6776970bdb5e5ba3ba.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11175  10.6084/m9.figshare.12229565    11176          ASC-US        768
#
#        nucleus_y
# 11175        516
# AAAAAAAAAAAAAAAAAAAAA
# 11176
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11176.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11176
#        image_id                        image_filename  \
# 11230        13  ac1ed15ddc7fb3d7e6a9c7521eeebe78.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11230  10.6084/m9.figshare.12229559    11231          ASC-US        290
#
#        nucleus_y
# 11230        598
# AAAAAAAAAAAAAAAAAAAAA
# 11231
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11231.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11231
#        image_id                        image_filename  \
# 11231        13  ac1ed15ddc7fb3d7e6a9c7521eeebe78.png
#
#                           image_doi  cell_id bethesda_system  nucleus_x  \
# 11231  10.6084/m9.figshare.12229559    11232          ASC-US        605
#
#        nucleus_y
# 11231        745
# AAAAAAAAAAAAAAAAAAAAA
# 11232
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/11232.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 11232
#       image_id                        image_filename  \
# 1124       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1124  10.6084/m9.figshare.12230795     1125          ASC-US        465
#
#       nucleus_y
# 1124        766
# AAAAAAAAAAAAAAAAAAAAA
# 1125
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/1125.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 1125
#       image_id                        image_filename  \
# 1125       372  67f61d22243d7d51469eee3071e688cb.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 1125  10.6084/m9.figshare.12230795     1126          ASC-US        502
#
#       nucleus_y
# 1125        686
# AAAAAAAAAAAAAAAAAAAAA
# 1126
# --------------
#
#
#
# ...
# 8046
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8046.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8046
#       image_id                        image_filename  \
# 8051        84  c7adf1972424f069b6355c500962722f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8051  10.6084/m9.figshare.12229784     8052          ASC-US        681
#
#       nucleus_y
# 8051        748
# AAAAAAAAAAAAAAAAAAAAA
# 8052
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8052.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8052
#       image_id                        image_filename  \
# 8052        84  c7adf1972424f069b6355c500962722f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8052  10.6084/m9.figshare.12229784     8053          ASC-US        583
#
#       nucleus_y
# 8052        570
# AAAAAAAAAAAAAAAAAAAAA
# 8053
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8053.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8053
#       image_id                        image_filename  \
# 8102        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8102  10.6084/m9.figshare.12229787     8103          ASC-US       1085
#
#       nucleus_y
# 8102        380
# AAAAAAAAAAAAAAAAAAAAA
# 8103
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8103.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8103
#       image_id                        image_filename  \
# 8103        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8103  10.6084/m9.figshare.12229787     8104          ASC-US        857
#
#       nucleus_y
# 8103        470
# AAAAAAAAAAAAAAAAAAAAA
# 8104
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8104.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8104
#       image_id                        image_filename  \
# 8104        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8104  10.6084/m9.figshare.12229787     8105          ASC-US        437
#
#       nucleus_y
# 8104        901
# AAAAAAAAAAAAAAAAAAAAA
# 8105
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8105.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8105
#       image_id                        image_filename  \
# 8105        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8105  10.6084/m9.figshare.12229787     8106          ASC-US        363
#
#       nucleus_y
# 8105        375
# AAAAAAAAAAAAAAAAAAAAA
# 8106
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8106.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8106
#       image_id                        image_filename  \
# 8106        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8106  10.6084/m9.figshare.12229787     8107          ASC-US        198
#
#       nucleus_y
# 8106        419
# AAAAAAAAAAAAAAAAAAAAA
# 8107
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8107.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8107
#       image_id                        image_filename  \
# 8122        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8122  10.6084/m9.figshare.12229787     8123          ASC-US        942
#
#       nucleus_y
# 8122        356
# AAAAAAAAAAAAAAAAAAAAA
# 8123
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8123.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8123
#       image_id                        image_filename  \
# 8123        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8123  10.6084/m9.figshare.12229787     8124          ASC-US       1033
#
#       nucleus_y
# 8123        715
# AAAAAAAAAAAAAAAAAAAAA
# 8124
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8124.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8124
#       image_id                        image_filename  \
# 8128        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8128  10.6084/m9.figshare.12229787     8129          ASC-US       1148
#
#       nucleus_y
# 8128        470
# AAAAAAAAAAAAAAAAAAAAA
# 8129
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8129.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8129
#       image_id                        image_filename  \
# 8129        85  6bb20c67c4013e8805d0f64315b9bcb1.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8129  10.6084/m9.figshare.12229787     8130          ASC-US       1012
#
#       nucleus_y
# 8129        591
# AAAAAAAAAAAAAAAAAAAAA
# 8130
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8130.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8130
#      image_id                        image_filename  \
# 813       386  855ef72948b5ef0f051083d1cceca3f9.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 813  10.6084/m9.figshare.12230843      814          ASC-US        603
#
#      nucleus_y
# 813        492
# AAAAAAAAAAAAAAAAAAAAA
# 814
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/814.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 814
#       image_id                        image_filename  \
# 8274        78  408929e7f250196167bf4418c08fd999.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 8274  10.6084/m9.figshare.12229766     8275          ASC-US        459
#
#       nucleus_y
# 8274        345
# AAAAAAAAAAAAAAAAAAAAA
# 8275
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/8275.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 8275
#      image_id                        image_filename  \
# 856       384  54562f3bda233bc849ce844c2d6d0809.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 856  10.6084/m9.figshare.12230837      857          ASC-US       1242
#
#      nucleus_y
# 856        304
# AAAAAAAAAAAAAAAAAAAAA
# 857
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/857.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 857
#      image_id                        image_filename  \
# 857       384  54562f3bda233bc849ce844c2d6d0809.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 857  10.6084/m9.figshare.12230837      858          ASC-US        327
#
#      nucleus_y
# 857        254
# AAAAAAAAAAAAAAAAAAAAA
# 858
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/858.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 858
#      image_id                        image_filename  \
# 858       384  54562f3bda233bc849ce844c2d6d0809.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 858  10.6084/m9.figshare.12230837      859          ASC-US        412
#
#      nucleus_y
# 858        230
# AAAAAAAAAAAAAAAAAAAAA
# 859
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/859.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 859
#      image_id                        image_filename  \
# 953       382  6cdee50089fd0f8937732789776cd025.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 953  10.6084/m9.figshare.12230828      954          ASC-US        762
#
#      nucleus_y
# 953        688
# AAAAAAAAAAAAAAAAAAAAA
# 954
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/954.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 954
#       image_id                        image_filename  \
# 9601        59  5223912945e356e1d6de561ad62a946f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9601  10.6084/m9.figshare.12229703     9602          ASC-US        636
#
#       nucleus_y
# 9601        143
# AAAAAAAAAAAAAAAAAAAAA
# 9602
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9602.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9602
#       image_id                        image_filename  \
# 9602        59  5223912945e356e1d6de561ad62a946f.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9602  10.6084/m9.figshare.12229703     9603          ASC-US        609
#
#       nucleus_y
# 9602        206
# AAAAAAAAAAAAAAAAAAAAA
# 9603
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9603.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9603
#       image_id                        image_filename  \
# 9709        54  c505515711e6d4153bd59214d979c041.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9709  10.6084/m9.figshare.12229688     9710          ASC-US       1120
#
#       nucleus_y
# 9709        586
# AAAAAAAAAAAAAAAAAAAAA
# 9710
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9710.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9710
#       image_id                        image_filename  \
# 9710        54  c505515711e6d4153bd59214d979c041.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9710  10.6084/m9.figshare.12229688     9711          ASC-US       1048
#
#       nucleus_y
# 9710        662
# AAAAAAAAAAAAAAAAAAAAA
# 9711
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9711.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9711
#      image_id                        image_filename  \
# 974       381  f503e5ca8eb5564129dcf3b1b78d8f6f.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 974  10.6084/m9.figshare.12230825      975          ASC-US        413
#
#      nucleus_y
# 974        557
# AAAAAAAAAAAAAAAAAAAAA
# 975
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/975.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 975
#      image_id                        image_filename  \
# 975       381  f503e5ca8eb5564129dcf3b1b78d8f6f.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 975  10.6084/m9.figshare.12230825      976          ASC-US        439
#
#      nucleus_y
# 975        520
# AAAAAAAAAAAAAAAAAAAAA
# 976
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/976.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 976
#      image_id                        image_filename  \
# 976       381  f503e5ca8eb5564129dcf3b1b78d8f6f.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 976  10.6084/m9.figshare.12230825      977          ASC-US        317
#
#      nucleus_y
# 976        848
# AAAAAAAAAAAAAAAAAAAAA
# 977
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/977.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 977
#      image_id                        image_filename  \
# 977       381  f503e5ca8eb5564129dcf3b1b78d8f6f.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 977  10.6084/m9.figshare.12230825      978          ASC-US        288
#
#      nucleus_y
# 977        710
# AAAAAAAAAAAAAAAAAAAAA
# 978
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/978.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 978
#      image_id                        image_filename  \
# 978       381  f503e5ca8eb5564129dcf3b1b78d8f6f.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 978  10.6084/m9.figshare.12230825      979          ASC-US        368
#
#      nucleus_y
# 978        738
# AAAAAAAAAAAAAAAAAAAAA
# 979
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/979.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 979
#      image_id                        image_filename  \
# 984       380  f9df91b71002aad46ba2415744b0816c.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 984  10.6084/m9.figshare.12230822      985          ASC-US        943
#
#      nucleus_y
# 984        372
# AAAAAAAAAAAAAAAAAAAAA
# 985
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/985.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 985
#       image_id                        image_filename  \
# 9850        53  d6e125d4b1ff838100937af08b912f0b.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9850  10.6084/m9.figshare.12229685     9851          ASC-US       1006
#
#       nucleus_y
# 9850        590
# AAAAAAAAAAAAAAAAAAAAA
# 9851
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9851.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9851
#       image_id                        image_filename  \
# 9851        53  d6e125d4b1ff838100937af08b912f0b.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9851  10.6084/m9.figshare.12229685     9852          ASC-US       1124
#
#       nucleus_y
# 9851        582
# AAAAAAAAAAAAAAAAAAAAA
# 9852
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9852.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9852
#       image_id                        image_filename  \
# 9852        53  d6e125d4b1ff838100937af08b912f0b.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9852  10.6084/m9.figshare.12229685     9853          ASC-US        373
#
#       nucleus_y
# 9852        863
# AAAAAAAAAAAAAAAAAAAAA
# 9853
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9853.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9853
#      image_id                        image_filename  \
# 985       380  f9df91b71002aad46ba2415744b0816c.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 985  10.6084/m9.figshare.12230822      986          ASC-US       1157
#
#      nucleus_y
# 985        335
# AAAAAAAAAAAAAAAAAAAAA
# 986
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/986.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 986
#      image_id                        image_filename  \
# 988       379  326be63a57e19af9bff9a7df786b9987.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 988  10.6084/m9.figshare.12230819      989          ASC-US        578
#
#      nucleus_y
# 988        520
# AAAAAAAAAAAAAAAAAAAAA
# 989
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/989.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 989
#     image_id                        image_filename  \
# 98       398  0cc6e576dac3046d279bba515e10a7a9.png
#
#                        image_doi  cell_id bethesda_system  nucleus_x  \
# 98  10.6084/m9.figshare.12230900       99          ASC-US       1113
#
#     nucleus_y
# 98         56
# AAAAAAAAAAAAAAAAAAAAA
# 99
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/99.png
# Valor do ratangulo: (0, 0, 179, 145)
# ASC-US 99
#      image_id                        image_filename  \
# 989       379  326be63a57e19af9bff9a7df786b9987.png
#
#                         image_doi  cell_id bethesda_system  nucleus_x  \
# 989  10.6084/m9.figshare.12230819      990          ASC-US        558
#
#      nucleus_y
# 989        555
# AAAAAAAAAAAAAAAAAAAAA
# 990
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/990.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 990
#       image_id                        image_filename  \
# 9947        50  6904abb84d55c002c01e119d241b18d9.png
#
#                          image_doi  cell_id bethesda_system  nucleus_x  \
# 9947  10.6084/m9.figshare.12229676     9948          ASC-US       1143
#
#       nucleus_y
# 9947        253
# AAAAAAAAAAAAAAAAAAAAA
# 9948
# --------------
#
#
#
# BBBBBBBBBBBBBBBBBBBBBBBBB
# ../data/base_recortada/ASC-US/9948.png
# Valor do ratangulo: (0, 0, 179, 179)
# ASC-US 9948

# %% [markdown]
# ### Analise das Mascaras

# %%
import math

# %%
img = cv2.imread("../data/base_mascara/LSIL/8.png")

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


threshold = 50


pixel_preto = np.sum(gray_img < threshold)


altura, largura = img.shape[:2]

pixels_total = altura *largura



print(f"Quantidade de pixels pretos: {pixel_preto}")
print(f"Quantidade total de pixels: {pixels_total}")
print(f"Porcentagem do tons de preto: {math.ceil((pixel_preto/pixels_total)*100)}")

# %%
lista_path_mascara = listar_imagens("../data/base_mascara/")
len(lista_path_mascara)
# Out:
# 606

# %%
lista_resultado = []

for each in lista_path_mascara:
  print(each)
  img = cv2.imread(each)
  gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  threshold = 50


  pixel_preto = np.sum(gray_img < threshold)


  altura, largura = img.shape[:2]

  pixels_total = altura *largura
  
  porcentagem = math.ceil((pixel_preto/pixels_total)*100)
  
  
  lista_resultado.append(porcentagem)
# Out:
# ../data/base_mascara/ASC\100.png
# ../data/base_mascara/ASC\1004.png
# ../data/base_mascara/ASC\10141.png
# ../data/base_mascara/ASC\10169.png
# ../data/base_mascara/ASC\10170.png
# ../data/base_mascara/ASC\10171.png
# ../data/base_mascara/ASC\10172.png
# ../data/base_mascara/ASC\10188.png
# ../data/base_mascara/ASC\10189.png
# ../data/base_mascara/ASC\10190.png
# ../data/base_mascara/ASC\10191.png
# ../data/base_mascara/ASC\10206.png
# ../data/base_mascara/ASC\10207.png
# ../data/base_mascara/ASC\10208.png
# ../data/base_mascara/ASC\10211.png
# ../data/base_mascara/ASC\10212.png
# ../data/base_mascara/ASC\10213.png
# ../data/base_mascara/ASC\10214.png
# ../data/base_mascara/ASC\10215.png
# ../data/base_mascara/ASC\10350.png
# ../data/base_mascara/ASC\10364.png
# ../data/base_mascara/ASC\10366.png
# ../data/base_mascara/ASC\10367.png
# ../data/base_mascara/ASC\10370.png
# ../data/base_mascara/ASC\10371.png
# ../data/base_mascara/ASC\10372.png
# ../data/base_mascara/ASC\10373.png
# ../data/base_mascara/ASC\10374.png
# ../data/base_mascara/ASC\10388.png
# ../data/base_mascara/ASC\10391.png
# ../data/base_mascara/ASC\1040.png
# ../data/base_mascara/ASC\10437.png
# ../data/base_mascara/ASC\1046.png
# ../data/base_mascara/ASC\1051.png
# ../data/base_mascara/ASC\1052.png
# ../data/base_mascara/ASC\1053.png
# ../data/base_mascara/ASC\1054.png
# ../data/base_mascara/ASC\1055.png
# ../data/base_mascara/ASC\1056.png
# ../data/base_mascara/ASC\10561.png
# ../data/base_mascara/ASC\1057.png
# ../data/base_mascara/ASC\1058.png
# ../data/base_mascara/ASC\1059.png
# ../data/base_mascara/ASC\1060.png
# ../data/base_mascara/ASC\1061.png
# ../data/base_mascara/ASC\1062.png
# ../data/base_mascara/ASC\1063.png
# ../data/base_mascara/ASC\1064.png
# ../data/base_mascara/ASC\10652.png
# ../data/base_mascara/ASC\10718.png
# ../data/base_mascara/ASC\10719.png
# ../data/base_mascara/ASC\1072.png
# ../data/base_mascara/ASC\10720.png
# ../data/base_mascara/ASC\1073.png
# ../data/base_mascara/ASC\1074.png
# ../data/base_mascara/ASC\1075.png
# ../data/base_mascara/ASC\10758.png
# ../data/base_mascara/ASC\10759.png
# ../data/base_mascara/ASC\1076.png
# ../data/base_mascara/ASC\1077.png
# ../data/base_mascara/ASC\10772.png
# ../data/base_mascara/ASC\10773.png
# ../data/base_mascara/ASC\1078.png
# ../data/base_mascara/ASC\1079.png
# ../data/base_mascara/ASC\1080.png
# ../data/base_mascara/ASC\1081.png
# ../data/base_mascara/ASC\10881.png
# ../data/base_mascara/ASC\10882.png
# ../data/base_mascara/ASC\10883.png
# ../data/base_mascara/ASC\10884.png
# ../data/base_mascara/ASC\10885.png
# ../data/base_mascara/ASC\10886.png
# ../data/base_mascara/ASC\10887.png
# ../data/base_mascara/ASC\1089.png
# ../data/base_mascara/ASC\1090.png
# ../data/base_mascara/ASC\1091.png
# ../data/base_mascara/ASC\10925.png
# ../data/base_mascara/ASC\10926.png
# ../data/base_mascara/ASC\10927.png
# ../data/base_mascara/ASC\10946.png
# ../data/base_mascara/ASC\10947.png
# ../data/base_mascara/ASC\10948.png
# ../data/base_mascara/ASC\10949.png
# ../data/base_mascara/ASC\10950.png
# ../data/base_mascara/ASC\10984.png
# ../data/base_mascara/ASC\10991.png
# ../data/base_mascara/ASC\11043.png
# ../data/base_mascara/ASC\11044.png
# ../data/base_mascara/ASC\1109.png
# ../data/base_mascara/ASC\1110.png
# ../data/base_mascara/ASC\1111.png
# ../data/base_mascara/ASC\11113.png
# ../data/base_mascara/ASC\11114.png
# ../data/base_mascara/ASC\1112.png
# ../data/base_mascara/ASC\1113.png
# ../data/base_mascara/ASC\1114.png
# ../data/base_mascara/ASC\11141.png
# ../data/base_mascara/ASC\1115.png
# ../data/base_mascara/ASC\11175.png
# ../data/base_mascara/ASC\11176.png
# ../data/base_mascara/ASC\11231.png
# ../data/base_mascara/ASC\11232.png
# ../data/base_mascara/ASC\1125.png
# ../data/base_mascara/ASC\1126.png
# ../data/base_mascara/ASC\11262.png
# ../data/base_mascara/ASC\1127.png
# ../data/base_mascara/ASC\11434.png
# ../data/base_mascara/ASC\11435.png
# ../data/base_mascara/ASC\11436.png
# ../data/base_mascara/ASC\11437.png
# ../data/base_mascara/ASC\11438.png
# ../data/base_mascara/ASC\11439.png
# ../data/base_mascara/ASC\11442.png
# ../data/base_mascara/ASC\11480.png
# ../data/base_mascara/ASC\11481.png
# ../data/base_mascara/ASC\11482.png
# ../data/base_mascara/ASC\11483.png
# ../data/base_mascara/ASC\11484.png
# ../data/base_mascara/ASC\11485.png
# ../data/base_mascara/ASC\11486.png
# ../data/base_mascara/ASC\11487.png
# ../data/base_mascara/ASC\11488.png
# ../data/base_mascara/ASC\11489.png
# ../data/base_mascara/ASC\11490.png
# ../data/base_mascara/ASC\11491.png
# ../data/base_mascara/ASC\11492.png
# ../data/base_mascara/ASC\11522.png
# ../data/base_mascara/ASC\1307.png
# ../data/base_mascara/ASC\1308.png
# ../data/base_mascara/ASC\1309.png
# ../data/base_mascara/ASC\1320.png
# ../data/base_mascara/ASC\1321.png
# ../data/base_mascara/ASC\1339.png
# ../data/base_mascara/ASC\1505.png
# ../data/base_mascara/ASC\1506.png
# ../data/base_mascara/ASC\1545.png
# ../data/base_mascara/ASC\1615.png
# ../data/base_mascara/ASC\1616.png
# ../data/base_mascara/ASC\1617.png
# ../data/base_mascara/ASC\1618.png
# ../data/base_mascara/ASC\1619.png
# ../data/base_mascara/ASC\1620.png
# ../data/base_mascara/ASC\1621.png
# ../data/base_mascara/ASC\1630.png
# ../data/base_mascara/ASC\1802.png
# ../data/base_mascara/ASC\1803.png
# ../data/base_mascara/ASC\1804.png
# ../data/base_mascara/ASC\1805.png
# ../data/base_mascara/ASC\1806.png
# ../data/base_mascara/ASC\1807.png
# ../data/base_mascara/ASC\1854.png
# ../data/base_mascara/ASC\1855.png
# ../data/base_mascara/ASC\1856.png
# ../data/base_mascara/ASC\1857.png
# ../data/base_mascara/ASC\1858.png
# ../data/base_mascara/ASC\2154.png
# ../data/base_mascara/ASC\2159.png
# ../data/base_mascara/ASC\2458.png
# ../data/base_mascara/ASC\2459.png
# ../data/base_mascara/ASC\2460.png
# ../data/base_mascara/ASC\2461.png
# ../data/base_mascara/ASC\2492.png
# ../data/base_mascara/ASC\2503.png
# ../data/base_mascara/ASC\2504.png
# ../data/base_mascara/ASC\2505.png
# ../data/base_mascara/ASC\2517.png
# ../data/base_mascara/ASC\2518.png
# ../data/base_mascara/ASC\2519.png
# ../data/base_mascara/ASC\2659.png
# ../data/base_mascara/ASC\2660.png
# ../data/base_mascara/ASC\2733.png
# ../data/base_mascara/ASC\2750.png
# ../data/base_mascara/ASC\2753.png
# ../data/base_mascara/ASC\2764.png
# ../data/base_mascara/ASC\2768.png
# ../data/base_mascara/ASC\2789.png
# ../data/base_mascara/ASC\2790.png
# ../data/base_mascara/ASC\2791.png
# ../data/base_mascara/ASC\2792.png
# ../data/base_mascara/ASC\2793.png
# ../data/base_mascara/ASC\2794.png
# ../data/base_mascara/ASC\2795.png
# ../data/base_mascara/ASC\2869.png
# ../data/base_mascara/ASC\2870.png
# ../data/base_mascara/ASC\2874.png
# ../data/base_mascara/ASC\2875.png
# ../data/base_mascara/ASC\2898.png
# ../data/base_mascara/ASC\2909.png
# ../data/base_mascara/ASC\2929.png
# ../data/base_mascara/ASC\2930.png
# ../data/base_mascara/ASC\2931.png
# ../data/base_mascara/ASC\2932.png
# ../data/base_mascara/ASC\2939.png
# ../data/base_mascara/ASC\2940.png
# ../data/base_mascara/ASC\2946.png
# ../data/base_mascara/ASC\2947.png
# ../data/base_mascara/ASC\2948.png
# ../data/base_mascara/ASC\2985.png
# ../data/base_mascara/ASC\2986.png
# ../data/base_mascara/ASC\3008.png
# ../data/base_mascara/ASC\3009.png
# ../data/base_mascara/ASC\3010.png
# ../data/base_mascara/ASC\3011.png
# ../data/base_mascara/ASC\3012.png
# ../data/base_mascara/ASC\3013.png
# ../data/base_mascara/ASC\3018.png
# ../data/base_mascara/ASC\3019.png
# ../data/base_mascara/ASC\3024.png
# ../data/base_mascara/ASC\3025.png
# ../data/base_mascara/ASC\3026.png
# ../data/base_mascara/ASC\3027.png
# ../data/base_mascara/ASC\3028.png
# ../data/base_mascara/ASC\3029.png
# ../data/base_mascara/ASC\3030.png
# ../data/base_mascara/ASC\3044.png
# ../data/base_mascara/ASC\3045.png
# ../data/base_mascara/ASC\3046.png
# ../data/base_mascara/ASC\3047.png
# ../data/base_mascara/ASC\3048.png
# ../data/base_mascara/ASC\3049.png
# ../data/base_mascara/ASC\3050.png
# ../data/base_mascara/ASC\3068.png
# ../data/base_mascara/ASC\3070.png
# ../data/base_mascara/ASC\3071.png
# ../data/base_mascara/ASC\3072.png
# ../data/base_mascara/ASC\3073.png
# ../data/base_mascara/ASC\3076.png
# ../data/base_mascara/ASC\3077.png
# ../data/base_mascara/ASC\3078.png
# ../data/base_mascara/ASC\3079.png
# ../data/base_mascara/ASC\3080.png
# ../data/base_mascara/ASC\3083.png
# ../data/base_mascara/ASC\3084.png
# ../data/base_mascara/ASC\3085.png
# ../data/base_mascara/ASC\3086.png
# ../data/base_mascara/ASC\3087.png
# ../data/base_mascara/ASC\3088.png
# ../data/base_mascara/ASC\3089.png
# ../data/base_mascara/ASC\3090.png
# ../data/base_mascara/ASC\3091.png
# ../data/base_mascara/ASC\3092.png
# ../data/base_mascara/ASC\3093.png
# ../data/base_mascara/ASC\3094.png
# ../data/base_mascara/ASC\3095.png
# ../data/base_mascara/ASC\3096.png
# ../data/base_mascara/ASC\3097.png
# ../data/base_mascara/ASC\3098.png
# ../data/base_mascara/ASC\3099.png
# ../data/base_mascara/ASC\3100.png
# ../data/base_mascara/ASC\3101.png
# ../data/base_mascara/ASC\3107.png
# ../data/base_mascara/ASC\3108.png
# ../data/base_mascara/ASC\3109.png
# ../data/base_mascara/ASC\3110.png
# ../data/base_mascara/ASC\3111.png
# ../data/base_mascara/ASC\3112.png
# ../data/base_mascara/ASC\3113.png
# ../data/base_mascara/ASC\3150.png
# ../data/base_mascara/ASC\3151.png
# ../data/base_mascara/ASC\3152.png
# ../data/base_mascara/ASC\3153.png
# ../data/base_mascara/ASC\3159.png
# ../data/base_mascara/ASC\3160.png
# ../data/base_mascara/ASC\3161.png
# ../data/base_mascara/ASC\3162.png
# ../data/base_mascara/ASC\3163.png
# ../data/base_mascara/ASC\3164.png
# ../data/base_mascara/ASC\3165.png
# ../data/base_mascara/ASC\3166.png
# ../data/base_mascara/ASC\3167.png
# ../data/base_mascara/ASC\3168.png
# ../data/base_mascara/ASC\3169.png
# ../data/base_mascara/ASC\3170.png
# ../data/base_mascara/ASC\3171.png
# ../data/base_mascara/ASC\3210.png
# ../data/base_mascara/ASC\3211.png
# ../data/base_mascara/ASC\3212.png
# ../data/base_mascara/ASC\3213.png
# ../data/base_mascara/ASC\3214.png
# ../data/base_mascara/ASC\3225.png
# ../data/base_mascara/ASC\3238.png
# ../data/base_mascara/ASC\3239.png
# ../data/base_mascara/ASC\3240.png
# ../data/base_mascara/ASC\3242.png
# ../data/base_mascara/ASC\3243.png
# ../data/base_mascara/ASC\3248.png
# ../data/base_mascara/ASC\3249.png
# ../data/base_mascara/ASC\3250.png
# ../data/base_mascara/ASC\3274.png
# ../data/base_mascara/ASC\3275.png
# ../data/base_mascara/ASC\3276.png
# ../data/base_mascara/ASC\3336.png
# ../data/base_mascara/ASC\3337.png
# ../data/base_mascara/ASC\3374.png
# ../data/base_mascara/ASC\3375.png
# ../data/base_mascara/ASC\3376.png
# ../data/base_mascara/ASC\3377.png
# ../data/base_mascara/ASC\3418.png
# ../data/base_mascara/ASC\3419.png
# ../data/base_mascara/ASC\3439.png
# ../data/base_mascara/ASC\3440.png
# ../data/base_mascara/ASC\3441.png
# ../data/base_mascara/ASC\3442.png
# ../data/base_mascara/ASC\3443.png
# ../data/base_mascara/ASC\3444.png
# ../data/base_mascara/ASC\3445.png
# ../data/base_mascara/ASC\3446.png
# ../data/base_mascara/ASC\3447.png
# ../data/base_mascara/ASC\3448.png
# ../data/base_mascara/ASC\3491.png
# ../data/base_mascara/ASC\3492.png
# ../data/base_mascara/ASC\3511.png
# ../data/base_mascara/ASC\3512.png
# ../data/base_mascara/ASC\3513.png
# ../data/base_mascara/ASC\3514.png
# ../data/base_mascara/ASC\3520.png
# ../data/base_mascara/ASC\3521.png
# ../data/base_mascara/ASC\3533.png
# ../data/base_mascara/ASC\3534.png
# ../data/base_mascara/ASC\3558.png
# ../data/base_mascara/ASC\3559.png
# ../data/base_mascara/ASC\3578.png
# ../data/base_mascara/ASC\3579.png
# ../data/base_mascara/ASC\3605.png
# ../data/base_mascara/ASC\3606.png
# ../data/base_mascara/ASC\3607.png
# ../data/base_mascara/ASC\3608.png
# ../data/base_mascara/ASC\3613.png
# ../data/base_mascara/ASC\3643.png
# ../data/base_mascara/ASC\3664.png
# ../data/base_mascara/ASC\3673.png
# ../data/base_mascara/ASC\3674.png
# ../data/base_mascara/ASC\3690.png
# ../data/base_mascara/ASC\3709.png
# ../data/base_mascara/ASC\3739.png
# ../data/base_mascara/ASC\3740.png
# ../data/base_mascara/ASC\3758.png
# ../data/base_mascara/ASC\3761.png
# ../data/base_mascara/ASC\3785.png
# ../data/base_mascara/ASC\3786.png
# ../data/base_mascara/ASC\3797.png
# ../data/base_mascara/ASC\3798.png
# ../data/base_mascara/ASC\3802.png
# ../data/base_mascara/ASC\3803.png
# ../data/base_mascara/ASC\3844.png
# ../data/base_mascara/ASC\3853.png
# ../data/base_mascara/ASC\3854.png
# ../data/base_mascara/ASC\3855.png
# ../data/base_mascara/ASC\3856.png
# ../data/base_mascara/ASC\3915.png
# ../data/base_mascara/ASC\3916.png
# ../data/base_mascara/ASC\4899.png
# ../data/base_mascara/ASC\4900.png
# ../data/base_mascara/ASC\4914.png
# ../data/base_mascara/ASC\4915.png
# ../data/base_mascara/ASC\4916.png
# ../data/base_mascara/ASC\4924.png
# ../data/base_mascara/ASC\4925.png
# ../data/base_mascara/ASC\4926.png
# ../data/base_mascara/ASC\4927.png
# ../data/base_mascara/ASC\4928.png
# ../data/base_mascara/ASC\4929.png
# ../data/base_mascara/ASC\4930.png
# ../data/base_mascara/ASC\4938.png
# ../data/base_mascara/ASC\4939.png
# ../data/base_mascara/ASC\4940.png
# ../data/base_mascara/ASC\4949.png
# ../data/base_mascara/ASC\4950.png
# ../data/base_mascara/ASC\4951.png
# ../data/base_mascara/ASC\4997.png
# ../data/base_mascara/ASC\4998.png
# ../data/base_mascara/ASC\4999.png
# ../data/base_mascara/ASC\5003.png
# ../data/base_mascara/ASC\5004.png
# ../data/base_mascara/ASC\5015.png
# ../data/base_mascara/ASC\5025.png
# ../data/base_mascara/ASC\5032.png
# ../data/base_mascara/ASC\5033.png
# ../data/base_mascara/ASC\5036.png
# ../data/base_mascara/ASC\5037.png
# ../data/base_mascara/ASC\5038.png
# ../data/base_mascara/ASC\5039.png
# ../data/base_mascara/ASC\5040.png
# ../data/base_mascara/ASC\5060.png
# ../data/base_mascara/ASC\5061.png
# ../data/base_mascara/ASC\5080.png
# ../data/base_mascara/ASC\5081.png
# ../data/base_mascara/ASC\5090.png
# ../data/base_mascara/ASC\5098.png
# ../data/base_mascara/ASC\5099.png
# ../data/base_mascara/ASC\5150.png
# ../data/base_mascara/ASC\5186.png
# ../data/base_mascara/ASC\5187.png
# ../data/base_mascara/ASC\5188.png
# ../data/base_mascara/ASC\5189.png
# ../data/base_mascara/ASC\5190.png
# ../data/base_mascara/ASC\5191.png
# ../data/base_mascara/ASC\5192.png
# ../data/base_mascara/ASC\5204.png
# ../data/base_mascara/ASC\5205.png
# ../data/base_mascara/ASC\5206.png
# ../data/base_mascara/ASC\5207.png
# ../data/base_mascara/ASC\5208.png
# ../data/base_mascara/ASC\5209.png
# ../data/base_mascara/ASC\5210.png
# ../data/base_mascara/ASC\5211.png
# ../data/base_mascara/ASC\5212.png
# ../data/base_mascara/ASC\5213.png
# ../data/base_mascara/ASC\5217.png
# ../data/base_mascara/ASC\5218.png
# ../data/base_mascara/ASC\5219.png
# ../data/base_mascara/ASC\5261.png
# ../data/base_mascara/ASC\5262.png
# ../data/base_mascara/ASC\5263.png
# ../data/base_mascara/ASC\5267.png
# ../data/base_mascara/ASC\5269.png
# ../data/base_mascara/ASC\5270.png
# ../data/base_mascara/ASC\5275.png
# ../data/base_mascara/ASC\5276.png
# ../data/base_mascara/ASC\5324.png
# ../data/base_mascara/ASC\5325.png
# ../data/base_mascara/ASC\5326.png
# ../data/base_mascara/ASC\5346.png
# ../data/base_mascara/ASC\5347.png
# ../data/base_mascara/ASC\5362.png
# ../data/base_mascara/ASC\5363.png
# ../data/base_mascara/ASC\5364.png
# ../data/base_mascara/ASC\5365.png
# ../data/base_mascara/ASC\5366.png
# ../data/base_mascara/ASC\5418.png
# ../data/base_mascara/ASC\5449.png
# ../data/base_mascara/ASC\5464.png
# ../data/base_mascara/ASC\5482.png
# ../data/base_mascara/ASC\5527.png
# ../data/base_mascara/ASC\5547.png
# ../data/base_mascara/ASC\5550.png
# ../data/base_mascara/ASC\5556.png
# ../data/base_mascara/ASC\5557.png
# ../data/base_mascara/ASC\5615.png
# ../data/base_mascara/ASC\5618.png
# ../data/base_mascara/ASC\5730.png
# ../data/base_mascara/ASC\5731.png
# ../data/base_mascara/ASC\6420.png
# ../data/base_mascara/ASC\6421.png
# ../data/base_mascara/ASC\728.png
# ../data/base_mascara/ASC\758.png
# ../data/base_mascara/ASC\759.png
# ../data/base_mascara/ASC\760.png
# ../data/base_mascara/ASC\761.png
# ../data/base_mascara/ASC\762.png
# ../data/base_mascara/ASC\7674.png
# ../data/base_mascara/ASC\7675.png
# ../data/base_mascara/ASC\7676.png
# ../data/base_mascara/ASC\7680.png
# ../data/base_mascara/ASC\7681.png
# ../data/base_mascara/ASC\7693.png
# ../data/base_mascara/ASC\7694.png
# ../data/base_mascara/ASC\7695.png
# ../data/base_mascara/ASC\7713.png
# ../data/base_mascara/ASC\7714.png
# ../data/base_mascara/ASC\7715.png
# ../data/base_mascara/ASC\7770.png
# ../data/base_mascara/ASC\7790.png
# ../data/base_mascara/ASC\7791.png
# ../data/base_mascara/ASC\7792.png
# ../data/base_mascara/ASC\7819.png
# ../data/base_mascara/ASC\7820.png
# ../data/base_mascara/ASC\7821.png
# ../data/base_mascara/ASC\7874.png
# ../data/base_mascara/ASC\7875.png
# ../data/base_mascara/ASC\7876.png
# ../data/base_mascara/ASC\7877.png
# ../data/base_mascara/ASC\7887.png
# ../data/base_mascara/ASC\7911.png
# ../data/base_mascara/ASC\7919.png
# ../data/base_mascara/ASC\7920.png
# ../data/base_mascara/ASC\7921.png
# ../data/base_mascara/ASC\7922.png
# ../data/base_mascara/ASC\7923.png
# ../data/base_mascara/ASC\7924.png
# ../data/base_mascara/ASC\7951.png
# ../data/base_mascara/ASC\7977.png
# ../data/base_mascara/ASC\7978.png
# ../data/base_mascara/ASC\7979.png
# ../data/base_mascara/ASC\7994.png
# ../data/base_mascara/ASC\7995.png
# ../data/base_mascara/ASC\8008.png
# ../data/base_mascara/ASC\801.png
# ../data/base_mascara/ASC\802.png
# ../data/base_mascara/ASC\803.png
# ../data/base_mascara/ASC\8034.png
# ../data/base_mascara/ASC\8035.png
# ../data/base_mascara/ASC\8036.png
# ../data/base_mascara/ASC\8037.png
# ../data/base_mascara/ASC\8046.png
# ../data/base_mascara/ASC\8052.png
# ../data/base_mascara/ASC\8053.png
# ../data/base_mascara/ASC\8103.png
# ../data/base_mascara/ASC\8104.png
# ../data/base_mascara/ASC\8105.png
# ../data/base_mascara/ASC\8106.png
# ../data/base_mascara/ASC\8107.png
# ../data/base_mascara/ASC\8123.png
# ../data/base_mascara/ASC\8124.png
# ../data/base_mascara/ASC\8129.png
# ../data/base_mascara/ASC\8130.png
# ../data/base_mascara/ASC\814.png
# ../data/base_mascara/ASC\8275.png
# ../data/base_mascara/ASC\857.png
# ../data/base_mascara/ASC\858.png
# ../data/base_mascara/ASC\859.png
# ../data/base_mascara/ASC\954.png
# ../data/base_mascara/ASC\9602.png
# ../data/base_mascara/ASC\9603.png
# ../data/base_mascara/ASC\9710.png
# ../data/base_mascara/ASC\9711.png
# ../data/base_mascara/ASC\975.png
# ../data/base_mascara/ASC\976.png
# ../data/base_mascara/ASC\977.png
# ../data/base_mascara/ASC\978.png
# ../data/base_mascara/ASC\979.png
# ../data/base_mascara/ASC\985.png
# ../data/base_mascara/ASC\9851.png
# ../data/base_mascara/ASC\9852.png
# ../data/base_mascara/ASC\9853.png
# ../data/base_mascara/ASC\986.png
# ../data/base_mascara/ASC\989.png
# ../data/base_mascara/ASC\99.png
# ../data/base_mascara/ASC\990.png
# ../data/base_mascara/ASC\9948.png

# %%
len(lista_resultado)
# Out:
# 606

# %%
from collections import Counter

contagem = Counter(lista_resultado)

valores = list(contagem.keys())
frequencias = list(contagem.values())


plt.bar(valores, frequencias, color='blue')

plt.title("Porcentagem de Erro da Mascara - 90 Value Expand")
plt.xlabel("Porcentagem")
plt.ylabel("Quantidade de Img")

plt.show()

# %%
new_list = []

for freq, val in zip(frequencias, valores):
    print(f"A porcentagem {val} apareceu {freq} vezes")
# Out:
# A porcentagem 45 apareceu 13 vezes
# A porcentagem 42 apareceu 17 vezes
# A porcentagem 11 apareceu 4 vezes
# A porcentagem 41 apareceu 16 vezes
# A porcentagem 54 apareceu 7 vezes
# A porcentagem 18 apareceu 7 vezes
# A porcentagem 84 apareceu 5 vezes
# A porcentagem 15 apareceu 8 vezes
# A porcentagem 12 apareceu 4 vezes
# A porcentagem 28 apareceu 16 vezes
# A porcentagem 33 apareceu 9 vezes
# A porcentagem 24 apareceu 8 vezes
# A porcentagem 22 apareceu 13 vezes
# A porcentagem 87 apareceu 1 vezes
# A porcentagem 82 apareceu 9 vezes
# A porcentagem 23 apareceu 10 vezes
# A porcentagem 7 apareceu 1 vezes
# A porcentagem 30 apareceu 18 vezes
# A porcentagem 38 apareceu 7 vezes
# A porcentagem 25 apareceu 19 vezes
# A porcentagem 31 apareceu 17 vezes
# A porcentagem 20 apareceu 11 vezes
# A porcentagem 27 apareceu 16 vezes
# A porcentagem 88 apareceu 5 vezes
# A porcentagem 79 apareceu 5 vezes
# A porcentagem 97 apareceu 4 vezes
# A porcentagem 52 apareceu 9 vezes
# A porcentagem 90 apareceu 4 vezes
# A porcentagem 70 apareceu 2 vezes
# A porcentagem 60 apareceu 6 vezes
# A porcentagem 48 apareceu 13 vezes
# A porcentagem 44 apareceu 11 vezes
# A porcentagem 50 apareceu 12 vezes
# A porcentagem 58 apareceu 7 vezes
# A porcentagem 21 apareceu 9 vezes
# A porcentagem 32 apareceu 10 vezes
# A porcentagem 40 apareceu 10 vezes
# A porcentagem 73 apareceu 2 vezes
# A porcentagem 46 apareceu 8 vezes
# A porcentagem 35 apareceu 11 vezes
# A porcentagem 98 apareceu 4 vezes
# A porcentagem 75 apareceu 3 vezes
# A porcentagem 86 apareceu 4 vezes
# A porcentagem 99 apareceu 3 vezes
# A porcentagem 49 apareceu 12 vezes
# A porcentagem 43 apareceu 10 vezes
# A porcentagem 37 apareceu 14 vezes
# A porcentagem 51 apareceu 5 vezes
# A porcentagem 17 apareceu 5 vezes
# A porcentagem 69 apareceu 2 vezes
# A porcentagem 36 apareceu 12 vezes
# A porcentagem 14 apareceu 3 vezes
# A porcentagem 57 apareceu 7 vezes
# A porcentagem 34 apareceu 16 vezes
# A porcentagem 53 apareceu 4 vezes
# A porcentagem 55 apareceu 6 vezes
# A porcentagem 47 apareceu 9 vezes
# A porcentagem 89 apareceu 6 vezes
# A porcentagem 26 apareceu 6 vezes
# A porcentagem 72 apareceu 3 vezes
# A porcentagem 39 apareceu 8 vezes
# A porcentagem 66 apareceu 1 vezes
# A porcentagem 68 apareceu 4 vezes
# A porcentagem 29 apareceu 14 vezes
# A porcentagem 71 apareceu 1 vezes
# A porcentagem 10 apareceu 1 vezes
# A porcentagem 62 apareceu 4 vezes
# A porcentagem 92 apareceu 6 vezes
# A porcentagem 96 apareceu 2 vezes
# A porcentagem 16 apareceu 4 vezes
# A porcentagem 93 apareceu 6 vezes
# A porcentagem 56 apareceu 6 vezes
# A porcentagem 64 apareceu 6 vezes
# A porcentagem 78 apareceu 2 vezes
# A porcentagem 94 apareceu 2 vezes
# A porcentagem 91 apareceu 5 vezes
# A porcentagem 63 apareceu 3 vezes
# A porcentagem 83 apareceu 3 vezes
# A porcentagem 76 apareceu 1 vezes
# A porcentagem 100 apareceu 5 vezes
# A porcentagem 95 apareceu 2 vezes
# A porcentagem 13 apareceu 4 vezes
# A porcentagem 80 apareceu 1 vezes
# A porcentagem 8 apareceu 1 vezes
# A porcentagem 65 apareceu 2 vezes
# A porcentagem 19 apareceu 2 vezes
# A porcentagem 61 apareceu 2 vezes
# A porcentagem 74 apareceu 4 vezes
# A porcentagem 81 apareceu 3 vezes
# A porcentagem 59 apareceu 1 vezes
# A porcentagem 77 apareceu 1 vezes
# A porcentagem 85 apareceu 1 vezes

# %%
sum(frequencias), sum(valores)
# Out:
# (606, 4953)

# %%
frequencias_diferentes_100 = []
full_error = []
for freq, val in zip(frequencias, valores):
  if val != 100:
    frequencias_diferentes_100.append(freq)
  else:
    full_error.append(freq)

# %%
sum(frequencias_diferentes_100), sum(full_error)
# Out:
# (601, 5)

# %%
labels = ['Diferentes de 100', '100']

cores = ['blue', 'red']

soma_frequencias_diferentes_de_100 = sum(frequencias_diferentes_100)

frequencias = [soma_frequencias_diferentes_de_100, sum(full_error)]

# Posições das barras no eixo X
x = range(len(frequencias))

# Plotar o gráfico de barras
plt.bar(x, frequencias, color=cores)

# Adicionar título e rótulos
plt.title("Comparação da Frequência de Valores - 90 Value Expand")
plt.xlabel("Valores")
plt.ylabel("Frequência")

plt.xticks(x, labels)

plt.show()
